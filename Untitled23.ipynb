# %% [markdown]
# <a href="https://colab.research.google.com/github/sardorbekhasan/airline-passenger-satisfaction/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import cross_val_predict
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.svm import SVC

# %%
df = pd.read_csv('train_dataset.csv')
df.head()
# Out:
#    id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   1    Male  disloyal Customer   33  Business travel       Eco
# 1   2  Female     Loyal Customer   49  Business travel  Business
# 2   3  Female     Loyal Customer   43  Business travel       Eco
# 3   4  Female     Loyal Customer   27  Business travel  Business
# 4   5    Male     Loyal Customer   11  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              571                      2                                  3
# 1             1431                      4                                  1
# 2              867                      1                                  4
# 3             1550                      3                                  3
# 4              526                      3                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
df.shape
# Out:
# (10000, 24)

# %%
categorical_features = ['Gender','Customer Type', 'Type of Travel', 'Class']
numerical_features = ['Age', 'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']

# %%
df.corrwith(df['satisfaction'], numeric_only=True).abs().sort_values(ascending=False)
# Out:
# satisfaction                         1.000000
# Online boarding                      0.504986
# Inflight entertainment               0.400900
# Seat comfort                         0.342294
# On-board service                     0.326426
# Leg room service                     0.324368
# Cleanliness                          0.310338
# Flight Distance                      0.298703
# Inflight wifi service                0.277395
# Baggage handling                     0.247965
# Inflight service                     0.240584
# Checkin service                      0.232359
# Food and drink                       0.207854
# Ease of Online booking               0.164662
# Age                                  0.144302
# Departure/Arrival time convenient    0.067638
# Arrival Delay in Minutes             0.048650
# Departure Delay in Minutes           0.042960
# Gate location                        0.007169
# id                                   0.002931
# dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='mean'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])


pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('scaler', StandardScaler())
])

# %%
X = pipeline.fit_transform(df)
y = df['satisfaction']

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
tree_model = DecisionTreeClassifier(criterion='entropy', max_depth=None, min_samples_leaf=2, min_samples_split=10)
tree_model.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=2,
#                        min_samples_split=10)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100)
gb.fit(X, y)
# Out:
# GradientBoostingClassifier()

# %%
rf_model = RandomForestClassifier(max_depth=None, max_features='log2', min_samples_leaf=1, min_samples_split=2, n_estimators=500)
rf_model.fit(X, y)
# Out:
# RandomForestClassifier(max_features='log2', n_estimators=500)

# %%
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
estimators = [
    ('rf', RandomForestClassifier(max_depth=None, max_features='log2', min_samples_leaf=1, min_samples_split=2, n_estimators=500)),
    ('svm', SVC(kernel='sigmoid'))
]
model1 = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
model1.fit(X, y)
# Out:
# StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(max_features='log2',
#                                                        n_estimators=500)),
#                                ('svm', SVC(kernel='sigmoid'))],
#                    final_estimator=LogisticRegression())

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l2
from keras.optimizers import Adam

optimizer = Adam(learning_rate=0.001)
model2 = Sequential()
model2.add(Dense(128, activation='relu', input_dim=X.shape[1]))
model2.add(Dense(1, activation='sigmoid'))  # For binary classification
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
model2.fit(X, y, epochs=10)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8047 - loss: 0.4222
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9049 - loss: 0.2519
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9187 - loss: 0.2084
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9227 - loss: 0.1955
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9296 - loss: 0.1785
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9335 - loss: 0.1721
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9367 - loss: 0.1594
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9389 - loss: 0.1519
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9400 - loss: 0.1511
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9424 - loss: 0.1411

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, LearningRateScheduler

# Define the model
model2 = Sequential()
model2.add(Dense(128, activation='relu', input_dim=X.shape[1]))
model2.add(BatchNormalization())
model2.add(Dropout(0.5))
model2.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
model2.add(Dropout(0.5))
model2.add(Dense(1, activation='sigmoid'))  # For binary classification

# Compile the model with an optimizer and loss function
optimizer = Adam(learning_rate=0.001)
model2.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Learning rate schedule and early stopping
def lr_schedule(epoch, lr):
    return lr * 0.9 if epoch > 5 else lr

lr_scheduler = LearningRateScheduler(lr_schedule)
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

# Train the model with early stopping and learning rate scheduler
model2.fit(X, y, epochs=50, batch_size=64, validation_split=0.2, callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7684 - loss: 0.6589 - val_accuracy: 0.8970 - val_loss: 0.4319 - learning_rate: 0.0010
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8495 - loss: 0.4646 - val_accuracy: 0.9085 - val_loss: 0.3484 - learning_rate: 0.0010
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8845 - loss: 0.3884 - val_accuracy: 0.9155 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8938 - loss: 0.3517 - val_accuracy: 0.9195 - val_loss: 0.2906 - learning_rate: 0.0010
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9069 - loss: 0.3130 - val_accuracy: 0.9205 - val_loss: 0.2760 - learning_rate: 0.0010
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8974 - loss: 0.3254 - val_accuracy: 0.9250 - val_loss: 0.2613 - learning_rate: 0.0010
# Epoch 7/50
# ...

# %%
test_df = pd.read_csv('test_dataset.csv')
test_df.head()
# Out:
#    id  Gender   Customer Type  Age   Type of Travel     Class  \
# 0   1  Female  Loyal Customer   25  Personal Travel       Eco
# 1   2  Female  Loyal Customer   49  Business travel  Business
# 2   3    Male  Loyal Customer   51  Business travel  Business
# 3   4    Male  Loyal Customer   34  Business travel  Eco Plus
# 4   5    Male  Loyal Customer   34  Personal Travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             2704                      2                                  2
# 1             1623                      1                                  1
# 2              338                      4                                  4
# 3               95                      0                                  0
# 4              602                      4                                  4
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# ...

# %%
X_test = pipeline.fit_transform(test_df)

# %%
y_predict1 = knn.predict(X_test)
df1 = pd.DataFrame({'id':np.arange(1, len(y_predict1)+1),'satisfaction':y_predict1})
df1.to_csv('submission1.6.csv', index=False)

# %%
y_predict2 = tree_model.predict(X_test)
df2 = pd.DataFrame({'id':np.arange(1, len(y_predict2)+1),'satisfaction':y_predict2})
df2.to_csv('submission1.7.csv', index=False)

# %%
y_predict3 = rf_model.predict(X_test)
df3 = pd.DataFrame({'id':np.arange(1, len(y_predict3)+1),'satisfaction':y_predict3})
df3.to_csv('submission2.3.csv', index=False)

# %%
y_predict4 = model.predict(X_test)
df4 = pd.DataFrame({'id':np.arange(1, len(y_predict4)+1),'satisfaction':y_predict4})
df4.to_csv('submission2.4.csv', index=False)

# %%
y_predict5 = gb.predict(X_test)
df5 = pd.DataFrame({'id':np.arange(1, len(y_predict5)+1),'satisfaction':y_predict5})
df5.to_csv('submission1.8.csv', index=False)

# %%
y_predict6 = model1.predict(X_test)
df6 = pd.DataFrame({'id':np.arange(1, len(y_predict6)+1),'satisfaction':y_predict6})
df6.to_csv('submission2.5.csv', index=False)

# %%
y_predict7 = model2.predict(X_test)
y_predict7 = y_predict7.flatten()
df7 = pd.DataFrame({'id':np.arange(1, len(y_predict7)+1),'satisfaction':y_predict7})
df7.to_csv('submission3.3.csv', index=False)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
